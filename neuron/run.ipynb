# %%
#Emergent structures out of synchronized function

from main import NetworkModel

num_agents = 20 
beta = 5 #Amount of agents that are randomly activated during each step
num_steps = 500

model = NetworkModel(num_agents, beta, seed = 2)
for x in range(num_steps):
    model.step()

print(model.weight_matrix)

G = model.network()


#analyzer = NetworkClassifier(G)
#metrics = analyzer.network_characteristics()
#topology = analyzer.topology()
#
#print("Metrics:", metrics)
#print("Topology:", topology)
# Out:
# No weight update: Agent 18 and Agent 11
# No weight update: Agent 18 and Agent 19
# No weight update: Agent 11 and Agent 18
# No weight update: Agent 11 and Agent 19
# No weight update: Agent 19 and Agent 18
# No weight update: Agent 19 and Agent 11
# No weight update: Agent 17 and Agent 1
# No weight update: Agent 17 and Agent 8
# No weight update: Agent 17 and Agent 12
# No weight update: Agent 1 and Agent 17
# No weight update: Agent 1 and Agent 8
# No weight update: Agent 1 and Agent 12
# No weight update: Agent 8 and Agent 17
# No weight update: Agent 8 and Agent 1
# No weight update: Agent 8 and Agent 12
# No weight update: Agent 12 and Agent 17
# No weight update: Agent 12 and Agent 1
# No weight update: Agent 12 and Agent 8
# No weight update: Agent 3 and Agent 19
# Chain reaction: Agent 19 -> Integrator 19 -> Receiver 3
# No weight update: Agent 2 and Agent 0
# No weight update: Agent 2 and Agent 9
# No weight update: Agent 2 and Agent 18
# ...
